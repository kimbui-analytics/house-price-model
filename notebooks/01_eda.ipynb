# %%
import sys
print(sys.executable)
# Out:
# /Users/kimbui/Documents/house-price-model/.venv/bin/python

# %%
import pandas as pd
from pathlib import Path

DATA_PATH = Path("..") / "data" / "raw" / "train.csv"
df = pd.read_csv(DATA_PATH)

df.shape
# Out:
# (1460, 81)
